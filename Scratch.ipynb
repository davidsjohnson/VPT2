# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
mask = np.load("data/rdf/p3/seq_masks/masks/p3a/masks/000187_mask.npy")
orig = np.load("data/rdf/p4/seq_masks/masks/p4a/masks/000080_mask.npy")

print(mask.shape, orig.shape)
# Out:
# (192, 480, 3) (192, 480, 3)

# %%
plt.figure()
plt.subplot(121)
plt.imshow(mask)
plt.subplot(122)
plt.imshow(orig)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import re

# %%
r = r'\bin$'

res = re.search(r, 'into')

# %%
res

# %%
print(res)
# Out:
# None

# %%
def writer(x):
    title = 'Sir'
    name = (lambda x: title + ' ' + x)
    return name

# %%
who = writer("string")
who("a name")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-b1b28055a680> in <module>()
#       1 who = writer("string")
# ----> 2 who()
#
# TypeError: <lambda>() missing 1 required positional argument: 'x'

# %%
l = [1,2,3, 5, 5, 6, 7, 7, 7]

# %%
new_list = list(set([val for i, val in enumerate(l) if val in l[i+1:]]))

# %%
new_list
# Out:
# [5, 7]

# %%
files = np.load("data/rdf/mixed/orig_maskpaths.npy")

# %%
files[4500]
# Out:
# b'data/rdf/generated/p0/error1/scaled0.50.85/mask/masks/000180_mask.npy'
