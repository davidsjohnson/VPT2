# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

# %%
X_lh, X_rh = np.load("data/posture/all/X_lh.npy"), np.load("data/posture/all/X_rh.npy")

# %%
plt.imshow(X_rh[400].squeeze())
# Out:
# <img src="data:image/png;base64,..." width="640">
